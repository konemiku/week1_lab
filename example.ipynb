# %% [markdown]
# <a href="https://colab.research.google.com/github/konemiku/week1_lab/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Daniil Panferov"

# %%
my_enrollment_number = "A85205225012"

# %%
my_hobby = "gaming"

# %%
print("Hello, my name is {""}, and my my enrollment number is {""}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is Daniil Panferov, and my my enrollment number is A85205225012. I like gaming.
